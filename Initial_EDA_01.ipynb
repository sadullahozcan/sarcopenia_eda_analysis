# %% [markdown]
# <a href="https://colab.research.google.com/github/sadullahozcan/sarcopenia_eda_analysis/blob/main/Initial_EDA_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Veriyi Okuyalım**

# %%
df = pd.read_excel("/content/drive/MyDrive/SARCOPENIA_PROJECT/sarcopenia-data-set_columns_corrected.xlsx")

# %%
df.head(n=5)
# Out:
#    Unnamed: 0      Name  Order Gender   Age  Weight  Height  Waist    Hip  \
# 0           0  beyzanur      1      M  74.0    88.0   178.0  113.0  113.0
# 1           1  beyzanur      2      M  62.0   105.0   172.0  125.0  110.0
# 2           2  beyzanur      3      M  65.0    89.0   169.0  110.0  114.0
# 3           3  beyzanur      4      F  71.0    68.0   160.0  103.0  100.0
# 4           4  beyzanur      5      F  61.0    80.0   160.0  102.0  105.0
#
#    Smoking  ...  Work_Status  Exercise    AT   CST  Gait_Speed Grip_Str  STAR  \
# 0        1  ...            0  3-4/week  50.2  12.5        1.21     32.0  1.81
# 1        1  ...            0         0  49.0  12.1        1.42     47.0  1.38
# 2        0  ...            0  3-4/week  37.3   8.7        1.18     33.0  1.20
# 3        1  ...            0  1-2/week  29.5   8.3        1.23     25.0  1.11
# 4        0  ...            0  1-2/week  39.5  11.0        1.31     31.0  1.26
#
#     BMI  MMSE  Sarcopenia
# ...

# %%
df.tail(n=5)
# Out:
#       Unnamed: 0   Name  Order Gender   Age  Weight  Height  Waist    Hip  \
# 5011        5011  ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0
# 5012        5012  ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0
# 5013        5013  ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0
# 5014        5014  ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0
# 5015        5015  ÖZDEN   5016      F  83.0    78.0   163.0   97.0  112.0
#
#       Smoking  ...  Work_Status  Exercise    AT    CST  Gait_Speed Grip_Str  \
# 5011        0  ...            0         0  28.2  14.67        0.81     19.5
# 5012        0  ...            0  3-4/week  37.9   9.14        1.23     18.7
# 5013        0  ...            0         0  43.2  11.86        1.16     29.5
# 5014        0  ...            0         0  39.0  17.12        0.90     17.9
# 5015        0  ...            0         0  26.0  39.64        0.19     14.9
#
#       STAR    BMI  MMSE  Sarcopenia
# ...

# %% [markdown]
# **Verinin Boyutları**

# %%
df.shape
# Out:
# (5016, 44)

# %% [markdown]
# **Verinin Özellikleri**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Order', 'Gender', 'Age', 'Weight', 'Height',
#        'Waist', 'Hip', 'Smoking', 'Smoking (packet/year)', 'Alcohol',
#        'DM_Type2', 'DM_Type2_Duration', 'Insulin', 'DM_Type2_Drug',
#        'DM_Type2_Drug_Usage', 'Dyslipidemia', 'Dyslipidemia_duration', 'KAH',
#        'KAH_Duration', 'Hipotiroidi', 'Asthma', 'COPD', 'OP', 'HT',
#        'Duration_of_HT', 'N_HT', 'HT_drugs', 'HT_Drug_Usage',
#        'Duration_of_1HT', 'Education', 'Job', 'Status', 'Work_Status',
#        'Exercise', 'AT', 'CST', 'Gait_Speed', 'Grip_Str', 'STAR', 'BMI',
#        'MMSE', 'Sarcopenia'],
#       dtype='object')

# %% [markdown]
# # **Veri Hakkında Özet Bilgi**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5016 entries, 0 to 5015
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5016 non-null   int64
#  1   Name                   5016 non-null   object
#  2   Order                  5016 non-null   int64
#  3   Gender                 5016 non-null   object
#  4   Age                    5016 non-null   float64
#  5   Weight                 5016 non-null   float64
#  6   Height                 5016 non-null   float64
#  7   Waist                  5016 non-null   float64
#  8   Hip                    5016 non-null   float64
#  9   Smoking                5016 non-null   int64
#  10  Smoking (packet/year)  5016 non-null   float64
#  11  Alcohol                5016 non-null   object
#  12  DM_Type2               5016 non-null   int64
#  13  DM_Type2_Duration      5016 non-null   float64
# ...

# %% [markdown]
# # **Veri Setinde Yer Alan Verilerin Tipleri**

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# Name                      object
# Order                      int64
# Gender                    object
# Age                      float64
# Weight                   float64
# Height                   float64
# Waist                    float64
# Hip                      float64
# Smoking                    int64
# Smoking (packet/year)    float64
# Alcohol                   object
# DM_Type2                   int64
# DM_Type2_Duration        float64
# Insulin                    int64
# DM_Type2_Drug             object
# DM_Type2_Drug_Usage        int64
# Dyslipidemia               int64
# Dyslipidemia_duration    float64
# KAH                        int64
# KAH_Duration             float64
# Hipotiroidi                int64
# Asthma                     int64
# COPD                       int64
# OP                        object
# HT                         int64
# Duration_of_HT           float64
# N_HT                       int64
# ...

# %% [markdown]
# # **Yinelenen Veri Analizi**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # **DataFrame'deki Verilerin Açıklaması**

# %%
df.describe()
# Out:
#         Unnamed: 0        Order          Age       Weight       Height  \
# count  5016.000000  5016.000000  5016.000000  5016.000000  5016.000000
# mean   2507.500000  2508.500000    61.996810    76.580188   160.495906
# std    1448.138806  1448.138806     9.695544    13.698852     9.026025
# min       0.000000     1.000000    42.000000    34.000000   125.000000
# 25%    1253.750000  1254.750000    54.000000    67.000000   155.000000
# 50%    2507.500000  2508.500000    62.000000    76.000000   160.000000
# 75%    3761.250000  3762.250000    69.000000    85.000000   166.000000
# max    5015.000000  5016.000000    95.000000   137.000000   260.000000
#
#              Waist          Hip      Smoking  Smoking (packet/year)  \
# count  5016.000000  5016.000000  5016.000000            5016.000000
# mean     98.171936   111.008155     0.320375               8.190666
# std      18.991366    14.324857     0.466667              16.070171
# ...

# %% [markdown]
# # **Columns' Names Cleaning and Renaming**

# %%
df.rename(columns ={'Weight ':'Weight','Height ':'Height','Waist ':'Waist'},inplace=True)

# %%
df[["Weight","Height","Waist"]]
# Out:
#       Weight  Height  Waist
# 0       88.0   178.0  113.0
# 1      105.0   172.0  125.0
# 2       89.0   169.0  110.0
# 3       68.0   160.0  103.0
# 4       80.0   160.0  102.0
# ...      ...     ...    ...
# 5011    73.0   143.0  103.0
# 5012    78.0   160.0  100.0
# 5013    95.0   180.0  100.0
# 5014    96.0   161.0  106.0
# 5015    78.0   163.0   97.0
#
# [5016 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Order', 'Gender', 'Age', 'Weight', 'Height',
#        'Waist', 'Hip', 'Smoking', 'Smoking (packet/year)', 'Alcohol',
#        'DM_Type2', 'DM_Type2_Duration', 'Insulin', 'DM_Type2_Drug',
#        'DM_Type2_Drug_Usage', 'Dyslipidemia', 'Dyslipidemia_duration', 'KAH',
#        'KAH_Duration', 'Hipotiroidi', 'Asthma', 'COPD', 'OP', 'HT',
#        'Duration_of_HT', 'N_HT', 'HT_drugs', 'HT_Drug_Usage',
#        'Duration_of_1HT', 'Education', 'Job', 'Status', 'Work_Status',
#        'Exercise', 'AT', 'CST', 'Gait_Speed', 'Grip_Str', 'STAR', 'BMI',
#        'MMSE', 'Sarcopenia'],
#       dtype='object')

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Order', 'Gender', 'Age', 'Weight', 'Height', 'Waist', 'Hip',
#        'Smoking', 'Smoking (packet/year)', 'Alcohol', 'DM_Type2',
#        'DM_Type2_Duration', 'Insulin', 'DM_Type2_Drug', 'DM_Type2_Drug_Usage',
#        'Dyslipidemia', 'Dyslipidemia_duration', 'KAH', 'KAH_Duration',
#        'Hipotiroidi', 'Asthma', 'COPD', 'OP', 'HT', 'Duration_of_HT', 'N_HT',
#        'HT_drugs', 'HT_Drug_Usage', 'Duration_of_1HT', 'Education', 'Job',
#        'Status', 'Work_Status', 'Exercise', 'AT', 'CST', 'Gait_Speed',
#        'Grip_Str', 'STAR', 'BMI', 'MMSE', 'Sarcopenia'],
#       dtype='object')

# %% [markdown]
# # **Missing Value Analysis-1**

# %%
df.isnull()
# Out:
#       Unnamed: 0   Name  Order  Gender    Age  Weight  Height  Waist    Hip  \
# 0          False  False  False   False  False   False   False  False  False
# 1          False  False  False   False  False   False   False  False  False
# 2          False  False  False   False  False   False   False  False  False
# 3          False  False  False   False  False   False   False  False  False
# 4          False  False  False   False  False   False   False  False  False
# ...          ...    ...    ...     ...    ...     ...     ...    ...    ...
# 5011       False  False  False   False  False   False   False  False  False
# 5012       False  False  False   False  False   False   False  False  False
# 5013       False  False  False   False  False   False   False  False  False
# 5014       False  False  False   False  False   False   False  False  False
# 5015       False  False  False   False  False   False   False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Name                       0
# Order                      0
# Gender                     0
# Age                        0
# Weight                     0
# Height                     0
# Waist                      0
# Hip                        0
# Smoking                    0
# Smoking (packet/year)      0
# Alcohol                    0
# DM_Type2                   0
# DM_Type2_Duration          0
# Insulin                    0
# DM_Type2_Drug              0
# DM_Type2_Drug_Usage        0
# Dyslipidemia               0
# Dyslipidemia_duration      0
# KAH                        0
# KAH_Duration               0
# Hipotiroidi                0
# Asthma                     0
# COPD                       0
# OP                         0
# HT                         0
# Duration_of_HT             0
# N_HT                       0
# HT_drugs                   0
# HT_Drug_Usage              0
# Duration_of_1HT            0
# Education                  0
# ...

# %% [markdown]
# # **Missing Value Analysis-2**

# %%
df[(df.isnull().Weight == True)]
# Out:
# Empty DataFrame
# Columns: [Name, Order, Gender, Age, Weight, Height, Waist, Hip, Smoking, Smoking (packet/year), Alcohol, DM_Type2, DM_Type2_Duration, Insulin, DM_Type2_Drug, DM_Type2_Drug_Usage, Dyslipidemia, Dyslipidemia_duration, KAH, KAH_Duration, Hipotiroidi, Asthma, COPD, OP, HT, Duration_of_HT, N_HT, HT_drugs, HT_Drug_Usage, Duration_of_1HT, Education, Job, Status, Work_Status, Exercise, AT, CST, Gait_Speed, Grip_Str, STAR, BMI, MMSE, Sarcopenia]
# Index: []
#
# [0 rows x 43 columns]

# %%
df.fillna({"Weight": df["Weight"].mean() }, inplace=True)

# %%
df["Weight"].isnull().sum()

# %%
df.fillna({"Height": df["Height"].mean() }, inplace=True)

# %%
df["Height"].isnull().sum()

# %%
df.isnull().sum()

# %%
df.fillna({"Waist": df["Waist"].mean() }, inplace=True)

# %%
df.fillna({"Hip": df["Hip"].mean() }, inplace=True)

# %%
df.describe()

# %%
df.fillna({"Smoking (packet/year)": df["Smoking (packet/year)"].mean() }, inplace=True)

# %%
df.isnull().sum()

# %%
df["Alcohol"]

# %%
df.loc[df.Alcohol == "social", "Alcohol"] = 1
df.loc[df.Alcohol == "Regular", "Alcohol"] = 1
df.loc[df.Alcohol == "düzenli içici", "Alcohol"] = 1

# %%
print(df.loc[5004, "Alcohol"])

# %%
df["Alcohol"]

# %%
df.loc[(df.DM_Type2 == 0) & (df.DM_Type2_Duration.isnull()), "DM_Type2_Duration"] = 0

# %%
df.loc[(df.DM_Type2.isnull()) & (df.DM_Type2_Duration.isnull()), "DM_Type2_Duration"] = 0

# %%
df.DM_Type2_Duration.isnull().sum()

# %%
df.loc[(df.DM_Type2 == 1) & (df.DM_Type2_Duration.isnull()), "DM_Type2_Duration"] = df.DM_Type2_Duration.mean()

# %%
df.DM_Type2_Duration.isnull().sum()

# %%
df.isnull().sum()

# %%
df.loc[(df.DM_Type2 == 1) & (df.Insulin.isnull()), "Insulin"] = 1

# %%
df.Insulin.isnull().sum()

# %%
df.loc[(df.DM_Type2.isnull()) & (df.Insulin == 0), "DM_Type2"] = 0

# %%
df.isnull().sum()

# %%
df.rename(columns ={'DM__Type2_Drug':'DM_Type2_Drug'},inplace=True)

# %%
df.columns

# %%
df.DM_Type2_Drug.isnull().sum()

# %%
df.loc[(df.DM_Type2_Drug == "bilmiyor"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "diyet"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "ilaç başlanmamış henüz"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "ilaç kullanmıyor"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "İLAÇ KULLANMIYOR"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "ilaç kullanmıyormuş??"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "ilaçsız takip,diet"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "ilaçsız takip"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "no medication"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "none"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2_Drug == "without drug"), "DM_Type2_Drug"] = 0

# %%
df.loc[(df.DM_Type2 == 0) & (df.Insulin == 0), "DM_Type2_Drug"] = 0

# %%
df.DM_Type2_Drug.isnull().sum()

# %%
df.DM_Type2_Drug.value_counts()

# %%
df.loc[(df.DM_Type2_Drug.isnull()), "DM_Type2_Drug"] = 0

# %%
df.DM_Type2_Drug.isnull().sum()

# %%
df.DM_Type2_Drug.value_counts()

# %%
df["DM_Type2_Drug_Usage"] = (df.DM_Type2_Drug != 0).astype(int).astype(str)

# %%
print(df["DM_Type2_Drug_Usage"].value_counts())

# %%
new_column = df.pop("DM_Type2_Drug_Usage")

# %%
df.insert(15, "DM_Type2_Drug_Usage", new_column)

# %%
print(df["DM_Type2_Drug_Usage"].value_counts())

# %%
df.columns

# %%
df.loc[(df.Dyslipidemia > 1), "Dyslipidemia"] = 1

# %%
df.Dyslipidemia.value_counts()

# %%
df.Dyslipidemia_duration.isnull().sum()

# %%
df.loc[(df.Dyslipidemia == 1) & (df.Dyslipidemia_duration.isnull()), "Dyslipidemia_duration"] = df.Dyslipidemia_duration.mean()

# %%
df.loc[(df.Dyslipidemia == 0) & (df.Dyslipidemia_duration.isnull()), "Dyslipidemia_duration"] = 0

# %%
df.Dyslipidemia_duration.isnull().sum()

# %%
df.loc[(df.Statin_Colest_Drug == "not used drug"), "Statin_Colest_Drug"] = 0

# %%
df.drop('Statin_Colest_Drug',axis=1, inplace=True)

# %%
df.columns

# %%
df.to_excel("/content/drive/MyDrive/SARCOPENIA_PROJECT/sarcopenia-data-set_columns_corrected2.xlsx")

# %%
df.rename(columns ={'KAH duration':'KAH_Duration'},inplace=True)

# %%
df.KAH_Duration.describe()

# %%
df.loc[(df.KAH_Duration.isnull()), "KAH_Duration"] = df.KAH_Duration.mean()

# %%
df.KAH_Duration.isnull().sum()

# %%
df.loc[(df.Gender == "M") & (df.Age >= 70) & (df.OP.isnull()), "OP"] = 1

# %%
df.loc[(df.Gender == "F") & (df.Age >= 65) & (df.OP.isnull()), "OP"] = 1

# %%
df.OP.isnull().sum()

# %%
df.loc[(df.Gender == "M") & (df.Age < 70) & (df.OP.isnull()), "OP"] = 0

# %%
df.loc[(df.Gender == "F") & (df.Age < 65) & (df.OP.isnull()), "OP"] = 0

# %%
df.OP.isnull().sum()

# %%
df.Others.value_counts()

# %%
df.drop('Others',axis=1, inplace=True)

# %%
df.columns

# %%
df.HT.value_counts()

# %%
df.loc[(df.HT.isnull()), "HT"] = 0

# %%
df.HT.isnull().sum()

# %%
df.Type_HT.value_counts()

# %%
df.drop('Type_HT',axis=1, inplace=True)

# %%
df.rename(columns ={'Duration of HT':'Duration_of_HT','Duration of 1HT': 'Duration_of_1HT'},inplace=True)

# %%
df.columns

# %%
df.Duration_of_HT.isnull().sum()

# %%
df.loc[(df.HT == 1) & (df.Duration_of_HT.isnull()), "Duration_of_HT"] = df.Duration_of_HT.mean()

# %%
df.Duration_of_HT.isnull().sum()

# %%
df.loc[(df.Duration_of_HT.isnull()), "Duration_of_HT"] = 0

# %%
df.Duration_of_HT.isnull().sum()

# %%
df.loc[(df.N_HT.isnull()), "N_HT"] = df.N_HT.median()

# %%
df.N_HT.isnull().sum()

# %%
df.HT_drugs.isnull().sum()

# %%
df.loc[(df.HT_drugs == "?"), "HT_drugs"] = 0

# %%
df.loc[(df.HT_drugs == "0?"), "HT_drugs"] = 0

# %%
df.loc[(df.HT_drugs == "bilmiyor"), "HT_drugs"] = 0

# %%
df.loc[(df.HT_drugs == "henüz tedavi başlanmamış"), "HT_drugs"] = 0

# %%
df.loc[(df.HT_drugs == "ilaç kullanmıyor"), "HT_drugs"] = 0

# %%
df.loc[(df.HT_drugs.isnull()), "HT_drugs"] = 0

# %% [markdown]
# **New Column Adding**

# %%
df["HT_Drug_Usage"] = (df.HT_drugs != 0).astype(int).astype(str)

# %%
print(df["HT_Drug_Usage"].value_counts())

# %%
new_column = df.pop("HT_Drug_Usage")

# %%
df.insert(28, "HT_Drug_Usage", new_column)

# %%
df.columns

# %%
df.Duration_of_1HT.isnull().sum()

# %%
df.Duration_of_1HT.value_counts()

# %%
df.loc[(df.Duration_of_1HT.isnull()), "Duration_of_1HT"] = 0

# %%
df.Duration_of_1HT.isnull().sum()

# %%
df.to_excel("/content/drive/MyDrive/SARCOPENIA_PROJECT/sarcopenia-data-set_columns_corrected2.xlsx")

# %%
df.Education.value_counts()

# %%
df.loc[(df.Education == "Primary shool"), "Education"] = "Primary School"

# %%
df.loc[(df.Education == "primary school"), "Education"] = "Primary School"

# %%
df.loc[(df.Education == "secondary school"), "Education"] = "Secondary School"

# %%
df.loc[(df.Education == "high school"), "Education"] = "High School"

# %%
df.loc[(df.Education == "üniversity"), "Education"] = "University"

# %%
df.loc[(df.Education == "university"), "Education"] = "University"

# %%
df.loc[(df.Age >= 80) & (df.Education.isnull()), "Education"] = "illiterate"

# %%
df.loc[(df.Job == "worker") & (df.Education.isnull()), "Education"] = "Primary School"

# %%
df.loc[(df.Job == "işçi") & (df.Education.isnull()), "Education"] = "Primary School"

# %%
df.Education.value_counts()

# %%
df.loc[(df.Education == "primary shool"), "Education"] = "Primary School"

# %%
df.Education.isnull().sum()

# %%
df.loc[(df.Age >= 70) & (df.Education.isnull()), "Education"] = "Primary School"

# %%
df.loc[(df.Age >= 60) & (df.Education.isnull()), "Education"] = "Secondary School"

# %%
df.loc[(df.Age >= 50) & (df.Education.isnull()), "Education"] = "High School"

# %%
df.loc[(df.Education.isnull()), "Education"] = "University"

# %%
df.Education.isnull().sum()

# %%
df.Job.isnull().sum()

# %%
df.loc[(df.Job.isnull()) & (df.Status == "emekli"), "Job"] = "Retired"

# %%
df.loc[(df.Job.isnull()) & (df.Status == "retired"), "Job"] = "Retired"

# %%
df.loc[(df.Job.isnull()) & (df.Status == "Retired"), "Job"] = "Retired"

# %%
df.loc[(df.Job.isnull()) & (df.Status == "emekli veya çalışmıyor"), "Job"] = "Retired"

# %%
df.loc[(df.Job.isnull()) & (df.Status == "EMEKLİ/ÇALIŞMIYOR"), "Job"] = "Retired"

# %%
df.loc[(df.Job.isnull()) & (df.Status == "evhanımı"), "Job"] = "Housewife"

# %%
df.loc[(df.Job == "housewife"), "Job"] = "Housewife"

# %%
df.loc[(df.Job == "house wife"), "Job"] = "Housewife"

# %%
df.loc[(df.Job == "evhanımı"), "Job"] = "Housewife"

# %%
df.loc[(df.Job == "ev hanımı"), "Job"] = "Housewife"

# %%
df.loc[(df.Job.isnull()) & (df.Status == "Retired"), "Job"] = "Retired"

# %%
df.loc[(df.Job.isnull()), "Job"] = "Unknown"

# %%
df.Job.isnull().sum()

# %%
df.Job.value_counts()

# %%
df.Status.value_counts()

# %%
df.loc[(df.Status == "evhanımı"), "Status"] = "Not Working"

# %%
df.loc[df.Status.isin(["retired","Retired","emekli veya çalışmıyor","unemployed","çALIŞMIYOR","non working","ÇALIŞMIYORr","çalışmıuor","çalışmıyor","Unemployed","emekli","Not working","ÇALIŞMIYOR","EMEKLİ/ÇALIŞMIYOR","Retired/nonworking","Çalışmıyor","retired or not working","Emekli","Emekli veya çalışmıyor","EMEKLİ","Abstinence","ÇALŞIMIYOR","not working","Retire","none","Retiret","emekli vey çalışmıyor","çalışmıYOR","emekli çalışmıyor","çalışmıyoR","unemployedNone"]), "Status"] = "Not Working"

# %%
df.Status.value_counts()

# %%
df.Status.isnull().sum()

# %%
df.loc[(df.Job == "Housewife") & (df.Status.isnull()), "Status"] = "Not Working"

# %%
df.Status.isnull().sum()

# %%
df.loc[(df.Status.isnull()), "Status"] = "Unknown"

# %%
df.Status.isnull().sum()

# %%
df.loc[(df.Status == "#REF!"), "Status"] = "Working"

# %%
df["Work_Status"] = (~df.Status.isin(["Not Working", "Unknown"])).astype(int).astype(str)

# %%
df.Work_Status.value_counts()

# %%
new_column3 = df.pop("Work_Status")

# %%
df.insert(33, "Work_Status", new_column3)

# %%
df.columns
# Out:
# Index(['Name', 'Order', 'Gender', 'Age', 'Weight', 'Height', 'Waist', 'Hip',
#        'Smoking', 'Smoking (packet/year)', 'Alcohol', 'DM_Type2',
#        'DM_Type2_Duration', 'Insulin', 'DM_Type2_Drug', 'DM_Type2_Drug_Usage',
#        'Dyslipidemia', 'Dyslipidemia_duration', 'KAH', 'KAH_Duration',
#        'Hipotiroidi', 'Asthma', 'COPD', 'OP', 'HT', 'Duration_of_HT', 'N_HT',
#        'HT_drugs', 'HT_Drug_Usage', 'Duration_of_1HT', 'Education', 'Job',
#        'Status', 'Work_Status', 'Exercise', 'AT', 'CST', 'Gait_Speed',
#        'Grip_Str', 'STAR', 'BMI', 'MMSE', 'Sarcopenia'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                      object
# Order                      int64
# Gender                    object
# Age                      float64
# Weight                   float64
# Height                   float64
# Waist                    float64
# Hip                      float64
# Smoking                    int64
# Smoking (packet/year)    float64
# Alcohol                   object
# DM_Type2                   int64
# DM_Type2_Duration        float64
# Insulin                    int64
# DM_Type2_Drug             object
# DM_Type2_Drug_Usage        int64
# Dyslipidemia               int64
# Dyslipidemia_duration    float64
# KAH                        int64
# KAH_Duration             float64
# Hipotiroidi                int64
# Asthma                     int64
# COPD                       int64
# OP                        object
# HT                         int64
# Duration_of_HT           float64
# N_HT                       int64
# HT_drugs                  object
# ...

# %%
df.to_excel("/content/drive/MyDrive/SARCOPENIA_PROJECT/sarcopenia-data-set_columns_corrected.xlsx")

# %%
df.Exercise.value_counts()
# Out:
# Exercise
# 0           2910
# 3-4/week    1226
# 1-2/week     817
# Name: count, dtype: int64

# %%
df.Exercise.isnull().sum()
# Out:
# np.int64(63)

# %%
df.loc[(df.Gait_Speed <= 1) & (df.CST <= 12) & (df.Exercise.isnull()), "Exercise"] = 0

# %%
df.loc[(df.Exercise.isnull()), "Exercise"] = "1-2/week"

# %%
df.Exercise.value_counts()
# Out:
# Exercise
# 0           2928
# 3-4/week    1226
# 1-2/week     862
# Name: count, dtype: int64

# %%
df.Exercise.isnull().sum()
# Out:
# np.int64(0)

# %%
df.loc[(df.Exercise == 0) & (df.AT.isnull()), "AT"] = 0

# %%
df.loc[(df.AT.isnull()), "AT"] = df.AT.mean()

# %%
df.AT.isnull().sum()
# Out:
# np.int64(0)

# %%
df.loc[(df.CST.isnull()), "CST"] = df.CST.median()

# %%
df.loc[(df.Gait_Speed.isnull()), "Gait_Speed"] = df.Gait_Speed.mean()

# %%
df.Grip_Str.isnull().sum()
# Out:
# np.int64(3)

# %%
df.loc[(df.Grip_Str.isnull()), "Grip_Str"] = df.Grip_Str.median()

# %%
df.Grip_Str.isnull().sum()
# Out:
# np.int64(0)

# %%
df.STAR.isnull().sum()
# Out:
# np.int64(21)

# %%
df.loc[(df.STAR.isnull()), "STAR"] = df.STAR.mean()

# %%
df.BMI.isnull().sum()
# Out:
# np.int64(12)

# %%
print(df.BMI.mean())
# Out:
# 29.867751798561148

# %%
print(df.BMI.median())
# Out:
# 29.3

# %%
df.loc[(df.BMI.isnull()), "BMI"] = df.BMI.mean()

# %%
df.BMI.isnull().sum()
# Out:
# np.int64(0)

# %%
df.MMSE.isnull().sum()
# Out:
# np.int64(901)

# %%
df.MMSE.mean()
# Out:
# np.float64(27.620656136087486)

# %%
df.MMSE.median()
# Out:
# 28.0

# %%
df.loc[(df.MMSE.isnull()), "MMSE"] = df.MMSE.median()

# %%
df.MMSE.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **Outlier Analysis**

# %%
df.columns
# Out:
# Index(['Name', 'Order', 'Gender', 'Age', 'Weight', 'Height', 'Waist', 'Hip',
#        'Smoking', 'Smoking (packet/year)', 'Alcohol', 'DM_Type2',
#        'DM_Type2_Duration', 'Insulin', 'DM_Type2_Drug', 'DM_Type2_Drug_Usage',
#        'Dyslipidemia', 'Dyslipidemia_duration', 'KAH', 'KAH_Duration',
#        'Hipotiroidi', 'Asthma', 'COPD', 'OP', 'HT', 'Duration_of_HT', 'N_HT',
#        'HT_drugs', 'HT_Drug_Usage', 'Duration_of_1HT', 'Education', 'Job',
#        'Status', 'Work_Status', 'Exercise', 'AT', 'CST', 'Gait_Speed',
#        'Grip_Str', 'STAR', 'BMI', 'MMSE', 'Sarcopenia'],
#       dtype='object')

# %%
df.head(n=5)
# Out:
#        Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0  beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1  beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2  beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3  beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4  beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
#
#    Smoking (packet/year)  ... Work_Status  Exercise    AT   CST Gait_Speed  \
# 0                   10.0  ...           0  3-4/week  50.2  12.5       1.21
# 1                   30.0  ...           0         0  49.0  12.1       1.42
# 2                    0.0  ...           0  3-4/week  37.3   8.7       1.18
# 3                    5.0  ...           0  1-2/week  29.5   8.3       1.23
# 4                    0.0  ...           0  1-2/week  39.5  11.0       1.31
#
#    Grip_Str  STAR   BMI  MMSE  Sarcopenia
# 0      32.0  1.81  27.8  29.0           0
# ...

# %%
df.describe()
# Out:
#              Order          Age       Weight       Height        Waist  \
# count  5016.000000  5016.000000  5016.000000  5016.000000  5016.000000
# mean   2508.500000    61.996810    76.580188   160.495906    98.171936
# std    1448.138806     9.695544    13.698852     9.026025    18.991366
# min       1.000000    42.000000    34.000000   125.000000     0.000000
# 25%    1254.750000    54.000000    67.000000   155.000000    90.000000
# 50%    2508.500000    62.000000    76.000000   160.000000    98.171936
# 75%    3762.250000    69.000000    85.000000   166.000000   106.000000
# max    5016.000000    95.000000   137.000000   260.000000   915.000000
#
#                Hip      Smoking  Smoking (packet/year)     DM_Type2  \
# count  5016.000000  5016.000000            5016.000000  5016.000000
# mean    111.008155     0.320375               8.190666     0.304426
# std      14.324857     0.466667              16.070171     0.460210
# ...

# %%
def cap_outliers_iqr(df, column_name):
    """
    Identifies outliers in a specified DataFrame column using the 1.5 * IQR rule
    and replaces them with the calculated upper and lower bounds.

    Args:
        df (pd.DataFrame): The input DataFrame.
        column_name (str): The name of the numerical column to process.

    Returns:
        pd.DataFrame: A new DataFrame with outliers in the specified column capped.
    """
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the DataFrame.")
    if not pd.api.types.is_numeric_dtype(df[column_name]):
        raise TypeError(f"Column '{column_name}' is not numeric. IQR method requires numeric data.")

    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)

    # Calculate IQR (Interquartile Range)
    IQR = Q3 - Q1

    # Calculate Upper and Lower Bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(f"--- Outlier Capping for '{column_name}' ---")
    print(f"Q1: {Q1:.2f}")
    print(f"Q3: {Q3:.2f}")
    print(f"IQR: {IQR:.2f}")
    print(f"Lower Bound (Q1 - 1.5*IQR): {lower_bound:.2f}")
    print(f"Upper Bound (Q3 + 1.5*IQR): {upper_bound:.2f}")

    # Identify and replace outliers
    # Replace values below the lower_bound with the lower_bound
    df.loc[df[column_name] < lower_bound, column_name] = lower_bound
    # Replace values above the upper_bound with the upper_bound
    df.loc[df[column_name] > upper_bound, column_name] = upper_bound

    return df

# %%
cap_outliers_iqr(df, "Age")
# Out:
# --- Outlier Capping for 'Age' ---
# Q1: 54.00
# Q3: 69.00
# IQR: 15.00
# Lower Bound (Q1 - 1.5*IQR): 31.50
# Upper Bound (Q3 + 1.5*IQR): 91.50
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
print(df.loc[3577, "Age"])
# Out:
# 60.0

# %%
cap_outliers_iqr(df, "Weight")
# Out:
# --- Outlier Capping for 'Weight' ---
# Q1: 67.00
# Q3: 85.00
# IQR: 18.00
# Lower Bound (Q1 - 1.5*IQR): 40.00
# Upper Bound (Q3 + 1.5*IQR): 112.00
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
df.Weight.value_counts()
# Out:
# Weight
# 70.0    219
# 80.0    210
# 75.0    195
# 72.0    168
# 78.0    165
#        ...
# 40.0      3
# 46.0      3
# 41.0      2
# 43.0      2
# 44.0      1
# Name: count, Length: 74, dtype: int64

# %%
df.Weight.max()
# Out:
# 112.0

# %%
df.Height.max(),df.Height.min()
# Out:
# (260.0, 125.0)

# %%
cap_outliers_iqr(df, "Height")
# Out:
# --- Outlier Capping for 'Height' ---
# Q1: 155.00
# Q3: 166.00
# IQR: 11.00
# Lower Bound (Q1 - 1.5*IQR): 138.50
# Upper Bound (Q3 + 1.5*IQR): 182.50
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
df.Height.max(),df.Height.min()
# Out:
# (182.5, 138.5)

# %%
cap_outliers_iqr(df, "Waist")
# Out:
# --- Outlier Capping for 'Waist' ---
# Q1: 90.00
# Q3: 106.00
# IQR: 16.00
# Lower Bound (Q1 - 1.5*IQR): 66.00
# Upper Bound (Q3 + 1.5*IQR): 130.00
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
cap_outliers_iqr(df, "Hip")
# Out:
# --- Outlier Capping for 'Hip' ---
# Q1: 102.00
# Q3: 117.00
# IQR: 15.00
# Lower Bound (Q1 - 1.5*IQR): 79.50
# Upper Bound (Q3 + 1.5*IQR): 139.50
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
df.describe()
# Out:
#              Order          Age       Weight       Height        Waist  \
# count  5016.000000  5016.000000  5016.000000  5016.000000  5016.000000
# mean   2508.500000    61.994816    76.500244   160.451747    97.975963
# std    1448.138806     9.689233    13.444037     8.796252    12.560747
# min       1.000000    42.000000    40.000000   138.500000    66.000000
# 25%    1254.750000    54.000000    67.000000   155.000000    90.000000
# 50%    2508.500000    62.000000    76.000000   160.000000    98.171936
# 75%    3762.250000    69.000000    85.000000   166.000000   106.000000
# max    5016.000000    91.500000   112.000000   182.500000   130.000000
#
#                Hip      Smoking  Smoking (packet/year)     DM_Type2  \
# count  5016.000000  5016.000000            5016.000000  5016.000000
# mean    110.445157     0.320375               8.190666     0.304426
# std      11.617940     0.466667              16.070171     0.460210
# ...

# %%
df.rename({'Smoking (packet/year)':'Smoking_packet_year',},axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Order', 'Gender', 'Age', 'Weight', 'Height', 'Waist', 'Hip',
#        'Smoking', 'Smoking_packet_year', 'Alcohol', 'DM_Type2',
#        'DM_Type2_Duration', 'Insulin', 'DM_Type2_Drug', 'DM_Type2_Drug_Usage',
#        'Dyslipidemia', 'Dyslipidemia_duration', 'KAH', 'KAH_Duration',
#        'Hipotiroidi', 'Asthma', 'COPD', 'OP', 'HT', 'Duration_of_HT', 'N_HT',
#        'HT_drugs', 'HT_Drug_Usage', 'Duration_of_1HT', 'Education', 'Job',
#        'Status', 'Work_Status', 'Exercise', 'AT', 'CST', 'Gait_Speed',
#        'Grip_Str', 'STAR', 'BMI', 'MMSE', 'Sarcopenia'],
#       dtype='object')

# %%
df.Smoking_packet_year.min()
# Out:
# 0.0

# %%
df.Smoking_packet_year.describe()
# Out:
# count    5016.000000
# mean        8.190666
# std        16.070171
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        10.000000
# max       150.000000
# Name: Smoking_packet_year, dtype: float64

# %%
iqr = df.Smoking_packet_year.quantile(0.75) - df.Smoking_packet_year.quantile(0.25)
smoking_packet_upper_bound = df.Smoking_packet_year.quantile(0.75) + 1.5 * iqr
smoking_packet_upper_bound
# Out:
# np.float64(25.0)

# %%
df.Smoking_packet_year.median()
# Out:
# 0.0

# %%
df.Smoking_packet_year.value_counts()
# Out:
# Smoking_packet_year
# 0.0      3404
# 30.0      239
# 20.0      211
# 10.0      163
# 40.0      141
#          ...
# 98.0        1
# 34.0        1
# 49.0        1
# 19.0        1
# 111.0       1
# Name: count, Length: 68, dtype: int64

# %%
df.loc[(df.Smoking_packet_year >= smoking_packet_upper_bound), "Smoking_packet_year"] = smoking_packet_upper_bound

# %%
df.Smoking_packet_year.max()
# Out:
# 25.0

# %%
df.DM_Type2_Duration.max()
# Out:
# 40.0

# %%
df.DM_Type2_Duration.median()
# Out:
# 0.0

# %%
iqr = df.DM_Type2_Duration.quantile(0.75) - df.DM_Type2_Duration.quantile(0.25)
DM_upper_bound = df.DM_Type2_Duration.quantile(0.75) + 1.5 * iqr
DM_upper_bound
# Out:
# np.float64(7.5)

# %%
df.loc[(df.DM_Type2_Duration >= DM_upper_bound), "DM_Type2_Duration"] = df.DM_Type2_Duration.median()

# %%
df.Dyslipidemia_duration.max()
# Out:
# 40.0

# %%
df.Dyslipidemia_duration.median()
# Out:
# 0.0

# %%
iqr = df.Dyslipidemia_duration.quantile(0.75) - df.Dyslipidemia_duration.quantile(0.25)
Dyslipidemia_upper_bound = df.Dyslipidemia_duration.quantile(0.75) + 1.5 * iqr
Dyslipidemia_upper_bound
# Out:
# np.float64(0.0)

# %%
df.loc[(df.Dyslipidemia_duration >= Dyslipidemia_upper_bound), "Dyslipidemia_duration"] = df.Dyslipidemia_duration.median()

# %%
df.Dyslipidemia_duration.value_counts()
# Out:
# Dyslipidemia_duration
# 0.0    5016
# Name: count, dtype: int64

# %%
df.KAH_Duration.max(), df.KAH_Duration.min(), df.KAH_Duration.mean(), df.KAH_Duration.median()
# Out:
# (40.0, 0.0, np.float64(1.0354309995953055), 0.0)

# %%
iqr_kah = df.KAH_Duration.quantile(0.75) - df.KAH_Duration.quantile(0.25)
KAH_duration_upper_bound = df.KAH_Duration.quantile(0.75) + 1.5 * iqr_kah
KAH_duration_upper_bound
# Out:
# np.float64(0.0)

# %%
df.loc[(df.KAH_Duration >= KAH_duration_upper_bound), "KAH_Duration"] = df.KAH_Duration.median()

# %%
df.Duration_of_HT.max(), df.Duration_of_HT.min(), df.Duration_of_HT.mean(), df.Duration_of_HT.median()
# Out:
# (50.0, 0.0, np.float64(5.830736389107194), 2.0)

# %%
iqr_ht = df.Duration_of_HT.quantile(0.75) - df.Duration_of_HT.quantile(0.25)
Duration_of_HT_upper_bound = df.Duration_of_HT.quantile(0.75) + 1.5 * iqr_ht
Duration_of_HT_lower_bound = df.Duration_of_HT.quantile(0.25) - 1.5 * iqr_ht
Duration_of_HT_upper_bound, Duration_of_HT_lower_bound
# Out:
# (np.float64(25.0), np.float64(-15.0))

# %%
df.loc[(df.Duration_of_HT >= Duration_of_HT_upper_bound), "Duration_of_HT"] = df.Duration_of_HT.median()

# %%
df.Duration_of_1HT.max(), df.Duration_of_1HT.min(), df.Duration_of_1HT.mean(), df.Duration_of_1HT.median()
# Out:
# (50.0, 0.0, np.float64(3.417085326953748), 0.0)

# %%
iqr_1ht = df.Duration_of_1HT.quantile(0.75) - df.Duration_of_1HT.quantile(0.25)
Duration_of_1HT_upper_bound = df.Duration_of_1HT.quantile(0.75) + 1.5 * iqr_1ht
Duration_of_1HT_lower_bound = df.Duration_of_1HT.quantile(0.25) - 1.5 * iqr_1ht
Duration_of_1HT_upper_bound, Duration_of_1HT_lower_bound
# Out:
# (np.float64(12.5), np.float64(-7.5))

# %%
df.loc[(df.Duration_of_1HT >= Duration_of_1HT_upper_bound), "Duration_of_1HT"] = df.Duration_of_1HT.median()

# %%
df.AT.max(), df.AT.min(), df.AT.mean(), df.AT.median()
# Out:
# (73.0, 0.0, np.float64(36.17106102911847), 35.9)

# %%
cap_outliers_iqr(df, "AT")
# Out:
# --- Outlier Capping for 'AT' ---
# Q1: 30.20
# Q3: 41.60
# IQR: 11.40
# Lower Bound (Q1 - 1.5*IQR): 13.10
# Upper Bound (Q3 + 1.5*IQR): 58.70
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
cap_outliers_iqr(df, "CST")
# Out:
# --- Outlier Capping for 'CST' ---
# Q1: 9.00
# Q3: 12.90
# IQR: 3.90
# Lower Bound (Q1 - 1.5*IQR): 3.15
# Upper Bound (Q3 + 1.5*IQR): 18.75
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
cap_outliers_iqr(df, "Grip_Str")
# Out:
# --- Outlier Capping for 'Grip_Str' ---
# Q1: 20.00
# Q3: 31.00
# IQR: 11.00
# Lower Bound (Q1 - 1.5*IQR): 3.50
# Upper Bound (Q3 + 1.5*IQR): 47.50
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
cap_outliers_iqr(df, "BMI")
# Out:
# --- Outlier Capping for 'BMI' ---
# Q1: 26.30
# Q3: 32.90
# IQR: 6.60
# Lower Bound (Q1 - 1.5*IQR): 16.40
# Upper Bound (Q3 + 1.5*IQR): 42.80
#           Name  Order Gender   Age  Weight  Height  Waist    Hip  Smoking  \
# 0     beyzanur      1      M  74.0    88.0   178.0  113.0  113.0        1
# 1     beyzanur      2      M  62.0   105.0   172.0  125.0  110.0        1
# 2     beyzanur      3      M  65.0    89.0   169.0  110.0  114.0        0
# 3     beyzanur      4      F  71.0    68.0   160.0  103.0  100.0        1
# 4     beyzanur      5      F  61.0    80.0   160.0  102.0  105.0        0
# ...        ...    ...    ...   ...     ...     ...    ...    ...      ...
# 5011     ÖZDEN   5012      F  70.0    73.0   143.0  103.0  111.0        0
# 5012     ÖZDEN   5013      F  72.0    78.0   160.0  100.0  108.0        0
# 5013     ÖZDEN   5014      M  79.0    95.0   180.0  100.0  114.0        0
# 5014     ÖZDEN   5015      M  85.0    96.0   161.0  106.0  107.0        0
# ...

# %%
df.MMSE.max(), df.MMSE.min(), df.MMSE.mean(), df.MMSE.median()
# Out:
# (30.0, 9.0, np.float64(27.688795853269536), 28.0)

# %%
iqr_MMSE = df.MMSE.quantile(0.75) - df.MMSE.quantile(0.25)
MMSE_upper_bound = df.MMSE.quantile(0.75) + 1.5 * iqr_MMSE
MMSE_lower_bound = df.MMSE.quantile(0.25) - 1.5 * iqr_MMSE
MMSE_upper_bound, MMSE_lower_bound
# Out:
# (np.float64(32.0), np.float64(24.0))

# %%
df.loc[(df.MMSE <= MMSE_lower_bound), "MMSE"] = MMSE_lower_bound

# %%
df.to_excel("/content/drive/MyDrive/SARCOPENIA_PROJECT/sarcopenia-data-set_columns_corrected3.xlsx")
